# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

data=pd.read_csv("Book1.csv")
df=pd.DataFrame(data)
x=df[["A"]]
y=df["B"]
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3)
model=LinearRegression()
z=model.fit(x_train,y_train)
print(z)
pre=model.predict(x_test)
print(pre)
acc=r2_score(y_test,pre)
print(acc)
mse=mean_squared_error(y_test,pre)
print(int(mse))

print(model.intercept_)
print(model.coef_)
# Out:
# LinearRegression()
# [30. 20. 50.  5. 15. 45. 10.]
# 1.0
# 0
# 7.105427357601002e-15
# [5.]

# %%
pre1=model.predict([[210135]])
pre1
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1050675.])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

data=pd.read_csv("heights_weights.csv")
df=pd.DataFrame(data)
df
# Out:
#          Height      Weight  Male
# 0     73.847017  241.893563     1
# 1     68.781904  162.310473     1
# 2     74.110105  212.740856     1
# 3     71.730978  220.042470     1
# 4     69.881796  206.349801     1
# ...         ...         ...   ...
# 9995  66.172652  136.777454     0
# 9996  67.067155  170.867906     0
# 9997  63.867992  128.475319     0
# 9998  69.034243  163.852461     0
# 9999  61.944246  113.649103     0
#
# [10000 rows x 3 columns]

# %%
df=df.drop(columns="Male",axis=1)
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
x=df[["Height"]]
y=df["Weight"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
model=LinearRegression()
z=model.fit(x_train,y_train)
z
# Out:
# LinearRegression()

# %%
pre=model.predict(x_test)
pre
# Out:
# array([179.25411946, 180.34765156, 161.63849193, ..., 188.45953085,
#        129.84456058, 201.11830118], shape=(3000,))

# %%
acc=r2_score(y_test,pre)
print(acc)
# Out:
# 0.8577298529881874

# %%
mse=mean_squared_error(y_test,pre)
print(int(mse))
# Out:
# 148

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [7.69542535]
# -349.323348605016

# %%
for i in range(1,7):
    x=df[["Height"]]
    y=df["Weight"]
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    model=LinearRegression()
    acc=r2_score(y_test,pre)
    mse=mean_squared_error(y_test,pre)
    print(i,acc,int(mse))
# Out:
# 1 -0.8573552457495854 1987
# 2 -0.8403231847818877 1919
# 3 -0.8142385378418782 1876
# 4 -0.8059845140116839 1888
# 5 -0.8122841860497583 1810
# 6 -0.8504458330214397 1919

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
model=LinearRegression()
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)
print(acc,int(mse))
# Out:
# 0.8577298529881874 148

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x=y_test,y=pre)
plt.show()
