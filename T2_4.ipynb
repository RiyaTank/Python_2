# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

data=pd.read_csv("diabetes.csv")
df=pd.DataFrame(data)
print(df)

x=df.drop(columns=['Outcome'])
y=df['Outcome']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc=accuracy_score(y_test,pre)
print("Accuracy: ",acc*100)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72             35        0  33.6                     0.627   50        1
# 1              1       85             66             29        0  26.6                     0.351   31        0
# 2              8      183             64              0        0  23.3                     0.672   32        1
# 3              1       89             66             23       94  28.1                     0.167   21        0
# 4              0      137             40             35      168  43.1                     2.288   33        1
# ..           ...      ...            ...            ...      ...   ...                       ...  ...      ...
# 763           10      101             76             48      180  32.9                     0.171   63        0
# ...

# %%
r=confusion_matrix(y_test,pre)
r
# Out:
# array([[108,  43],
#        [ 32,  48]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(r,annot=True)
plt.show()b

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(r,annot=True,fmt='d')
plt.xlabel("actual")
plt.ylabel("predict")
plt.extictlab                                      
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(model.classes_)
# Out:
# [0 1]

# %%
accuracy=(108+48)/(108+43+32+48)
accuracy
# Out:
# 0.6753246753246753

# %%
error_rate=1-accuracy
error_rate
# Out:
# 0.3246753246753247

# %%
matrix_acc=(r[0,0]+r[1,1])/r.sum()
matrix_acc
# Out:
# np.float64(0.6753246753246753)

# %%
matrix_err=(r[0,1]+r[1,0])/r.sum()
matrix_err
# Out:
# np.float64(0.3246753246753247)

# %%
r
# Out:
# array([[108,  43],
#        [ 32,  48]])

# %%
precision=r[0,0]/(r[0,0]+r[1,0])
precision
# Out:
# np.float64(0.7714285714285715)

# %%
recall=r[0,0]/(r[0,0]+r[0,1])
recall
#recall(sensitivity)
# Out:
# np.float64(0.7152317880794702)

# %%
specificity=r[1,1]/(r[1,0]+r[1,1])
specificity
# Out:
# np.float64(0.6)

# %%
f1_score=(2*precision*recall)/(precision+recall)
f1_score
# Out:
# np.float64(0.7422680412371134)

# %%
print(classification_report(y_test,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       151
#            1       0.53      0.60      0.56        80
#
#     accuracy                           0.68       231
#    macro avg       0.65      0.66      0.65       231
# weighted avg       0.69      0.68      0.68       231

# %%
d={}
for i in range(1,11):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    acc=accuracy_score(y_test,pre)
    print("Accuracy: ",i," ",acc*100)
    d[i]=acc
print("maximum accuracy",i," ",max(d.values()))
# Out:
# Accuracy:  1   67.53246753246754
# Accuracy:  2   70.12987012987013
# Accuracy:  3   64.93506493506493
# Accuracy:  4   70.77922077922078
# Accuracy:  5   66.23376623376623
# Accuracy:  6   72.72727272727273
# Accuracy:  7   68.83116883116884
# Accuracy:  8   74.67532467532467
# Accuracy:  9   72.07792207792207
# Accuracy:  10   76.62337662337663
# maximum accuracy 10   0.7662337662337663

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

data=pd.read_csv("Iris.csv")
df=pd.DataFrame(data)
print(df)

x=df.drop(columns=['Species','Id'])
y=df['Species']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc=accuracy_score(y_test,pre)
print("Accuracy: ",acc*100)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1            5.1           3.5            1.4           0.2     Iris-setosa
# 1      2            4.9           3.0            1.4           0.2     Iris-setosa
# 2      3            4.7           3.2            1.3           0.2     Iris-setosa
# 3      4            4.6           3.1            1.5           0.2     Iris-setosa
# 4      5            5.0           3.6            1.4           0.2     Iris-setosa
# ..   ...            ...           ...            ...           ...             ...
# 145  146            6.7           3.0            5.2           2.3  Iris-virginica
# 146  147            6.3           2.5            5.0           1.9  Iris-virginica
# 147  148            6.5           3.0            5.2           2.0  Iris-virginica
# 148  149            6.2           3.4            5.4           2.3  Iris-virginica
# ...

# %%
r=confusion_matrix(y_test,pre)
r
# only true predictions
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])
